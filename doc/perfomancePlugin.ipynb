# %% [markdown]
# ## JASM

# %% [markdown]
# This section loads performance data specific to the 'JASM' configuration. Once loaded, it generates a series of regression plots using the `seaborn` and `matplotlib` libraries to visualize the relationships between data size ('size_data'), JASM execution time ('jasm_time_data'), and the number of instructions ('instructions').
#
# The generated plots are:
# 1. **JASM(MB) - Time(s) vs Size(MB):** Shows how JASM execution time varies with data size.
#
# 2. **Time vs. Instructions:** Visualizes the relationship between JASM execution time and the number of instructions.
#
# 3. **Instructions vs. Size:** Illustrates how the number of instructions relates to data size.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- Reemplaza esta sección con la carga de tus datos ---
# Por ejemplo, si tienes un archivo CSV:
# df = pd.read_csv('tu_archivo.csv')
# O si tus datos ya están en un DataFrame de pandas:
# df = tu_dataframe

# Datos proporcionados por el usuario:
data = {
    'dato_de_size': [4.2, 8.2, 12.5, 16.7, 20.9, 25.1, 29.3, 33.5, 37.7, 41.9,46.1,50.3,54.5,100.7,151,201.4,251.8],
    'dato_de_tiempo_jasm': [10.221, 16.9722, 24.7663, 32.024, 39.7123, 34.6556, 41.2383, 62.8587, 76.4986, 78.1198,62.7645,138.9035,154.973,129.3185,207.9264,283.1918,356.1276],
    'instructions': [274243,548486,822729,1096972,1371215,1645458,1919701,2193944,2468187,2742430,3016673,3290916,3565159,6581832,9872748,13163664,16454580]
}
df = pd.DataFrame(data)
# --------------------------------------------------------

# Crear una figura con 3 subplots en una fila
fig, axes = plt.subplots(1, 3, figsize=(18, 5)) # 1 fila, 3 columnas

# Primer gráfico: JASM(MB) - Time(s) vs Size(MB)
sns.regplot(x='dato_de_size', y='dato_de_tiempo_jasm', data=df, scatter_kws={'alpha':0.6}, ax=axes[0])
axes[0].set_title('JASM(MB)')
axes[0].set_xlabel('Size(MB)')
axes[0].set_ylabel('Time(s)')
axes[0].grid(True, linestyle='--', alpha=0.7)

# Segundo gráfico: Tiempo vs. Instrucciones
sns.regplot(x='instructions', y='dato_de_tiempo_jasm', data=df, scatter_kws={'alpha':0.6}, ax=axes[1])
axes[1].set_title('Tiempo vs. Instrucciones')
axes[1].set_xlabel('Instrucciones')
axes[1].set_ylabel('Dato de Tiempo')
axes[1].grid(True, linestyle='--', alpha=0.7)

# Tercer gráfico: Instrucciones vs. Size
sns.regplot(x='dato_de_size', y='instructions', data=df, scatter_kws={'alpha':0.6}, ax=axes[2])
axes[2].set_title('instructions vs. Size')
axes[2].set_xlabel('Dato de Size')
axes[2].set_ylabel('instructions')
axes[2].grid(True, linestyle='--', alpha=0.7)

plt.tight_layout() # Ajusta el diseño para evitar superposiciones
plt.show()

# %% [markdown]
# PLUGIN

# %% [markdown]
# This section loads performance data specific to the 'PLUGIN' configuration. Once loaded, it generates a series of regression plots using the `seaborn` and `matplotlib` libraries to visualize the relationships between data size ('size_data'), PLUGIN execution time ('plugin_time_data'), and the number of instructions ('instructions').
#
# The generated plots are:
# 1. **PLUGIN(MB) - Time(s) vs Size(MB):** Shows how the PLUGIN execution time varies with the data size.
#
# 2. **Time vs Instructions:** Visualizes the relationship between the PLUGIN execution time and the number of instructions.
#
# 3. **Instructions vs Size:** Illustrates how the number of instructions relates to the data size.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- Reemplaza esta sección con la carga de tus datos ---
# Por ejemplo, si tienes un archivo CSV:
# df = pd.read_csv('tu_archivo.csv')
# O si tus datos ya están en un DataFrame de pandas:
# df = tu_dataframe

# Datos proporcionados por el usuario:
data = {
    'dato_de_size': [4.2, 8.2, 12.5, 16.7, 20.9, 25.1, 29.3, 33.5, 37.7, 41.9,46.1,50.3,54.5,100.7,151,201.4,251.8],
    'dato_de_tiempo_plugin': [0.718,1.34,2.332,2.787,3.853,4.944,5.613,5.836,9.042,9.736,11.73,11.448,13.226,24.635,34.954,45.749,56.574],
    'instructions': [274243,548486,822729,1096972,1371215,1645458,1919701,2193944,2468187,2742430,3016673,3290916,3565159,6581832,9872748,13163664,16454580]
}
df = pd.DataFrame(data)
# --------------------------------------------------------

# Crear una figura con 3 subplots en una fila
fig, axes = plt.subplots(1, 3, figsize=(18, 5)) # 1 fila, 3 columnas

# Primer gráfico: JASM(MB) - Time(s) vs Size(MB)
sns.regplot(x='dato_de_size', y='dato_de_tiempo_plugin', data=df, scatter_kws={'alpha':0.6}, ax=axes[0])
axes[0].set_title('PLUGIN(MB)')
axes[0].set_xlabel('Size(MB)')
axes[0].set_ylabel('Time(s)')
axes[0].grid(True, linestyle='--', alpha=0.7)

# Segundo gráfico: Tiempo vs. Instrucciones
sns.regplot(x='instructions', y='dato_de_tiempo_plugin', data=df, scatter_kws={'alpha':0.6}, ax=axes[1])
axes[1].set_title('Tiempo vs. Instrucciones')
axes[1].set_xlabel('Instrucciones')
axes[1].set_ylabel('Dato de Tiempo')
axes[1].grid(True, linestyle='--', alpha=0.7)

# Tercer gráfico: Instrucciones vs. Size
sns.regplot(x='dato_de_size', y='instructions', data=df, scatter_kws={'alpha':0.6}, ax=axes[2])
axes[2].set_title('instructions vs. Size')
axes[2].set_xlabel('Dato de Size')
axes[2].set_ylabel('instructions')
axes[2].grid(True, linestyle='--', alpha=0.7)

plt.tight_layout() # Ajusta el diseño para evitar superposiciones
plt.show()

# %% [markdown]
# JASM VS PLUGIN OBJDUMP VS OBJDUMP

# %% [markdown]
# This section compares the performance of the 'JASM', 'PLUGIN', and 'OBJDUMP' configurations. It loads the time and instruction count data for each and generates regression plots using `seaborn` and `matplotlib` to visualize the differences.
#
# The generated plots are:
# 1. **Time (Plugin, JASM, and Objdump) vs. Instructions:** Shows how the execution time of each tool varies with the number of instructions.
#
# 2. **Time (Plugin, JASM, and Objdump) vs. Size:** Visualizes the relationship between the execution time of each tool and the size of the data.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'dato_de_size': [4.2, 8.2, 12.5, 16.7, 20.9, 25.1, 29.3, 33.5, 37.7, 41.9,46.1,50.3,54.5,100.7,151,201.4,251.8],
    'dato_de_tiempo_plugin': [0.718,1.34,2.332,2.787,3.853,4.944,5.613,5.836,9.042,9.736,11.73,11.448,13.226,24.635,34.954,45.749,56.574],
    'instructions': [274243,548486,822729,1096972,1371215,1645458,1919701,2193944,2468187,2742430,3016673,3290916,3565159,6581832,9872748,13163664,16454580],
    'dato_de_tiempo_jasm': [10.221, 16.9722, 24.7663, 32.024, 39.7123, 34.6556, 41.2383, 62.8587, 76.4986, 78.1198,62.7645,138.9035,154.973,129.3185,207.9264,283.1918,356.1276],
    'dato_de_tiempo_objdump': [0.319,0.645,1.135,1.549,1.991,2.31,2.735,3.219,5.094,5.7,6.204,6.781,7.306,14.468,20.373,27.169,34.069]
}
df = pd.DataFrame(data)

# Crear una figura con 2 subplots en una fila
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Primer gráfico: Tiempo de Plugin, JASM y OBJDUMP vs. Instrucciones
sns.regplot(x='instructions', y='dato_de_tiempo_plugin', data=df, scatter_kws={'alpha':0.6}, label='Plugin', ax=axes[0])
sns.regplot(x='instructions', y='dato_de_tiempo_jasm', data=df, scatter_kws={'alpha':0.6}, label='JASM', ax=axes[0])
sns.regplot(x='instructions', y='dato_de_tiempo_objdump', data=df, scatter_kws={'alpha':0.6}, label='Objdump', ax=axes[0])
axes[0].set_title('Time (Plugin, JASM y Objdump) vs. Instrucciones')
axes[0].set_xlabel('instructions')
axes[0].set_ylabel('Time (s)')
axes[0].grid(True, linestyle='--', alpha=0.7)
axes[0].legend()

# Segundo gráfico: Tiempo de Plugin, JASM y OBJDUMP vs. Size
sns.regplot(x='dato_de_size', y='dato_de_tiempo_plugin', data=df, scatter_kws={'alpha':0.6}, label='Plugin', ax=axes[1])
sns.regplot(x='dato_de_size', y='dato_de_tiempo_jasm', data=df, scatter_kws={'alpha':0.6}, label='JASM', ax=axes[1])
sns.regplot(x='dato_de_size', y='dato_de_tiempo_objdump', data=df, scatter_kws={'alpha':0.6}, label='Objdump', ax=axes[1])
axes[1].set_title('Tieme (Plugin, JASM y Objdump) vs. Size')
axes[1].set_xlabel('Size (MB)')
axes[1].set_ylabel('Time (s)')
axes[1].grid(True, linestyle='--', alpha=0.7)
axes[1].legend()

plt.tight_layout() # Ajusta el diseño para evitar superposiciones
plt.show()

# %% [markdown]
# GAIN

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import io

# --- Primer conjunto de datos: TIEMPO_PLUGIN vs JASM ---
data_text_plugin_jasm = """
TIEMPO_PLUGIN,JASM,VECES
0.718,10.221,14.23537604
1.34,16.9722,12.6658209
2.332,24.7663,10.62019726
2.787,32.024,11.49049157
3.853,39.7123,10.3068518
4.944,34.6556,7.009627832
5.613,41.2383,7.346926777
5.836,62.8587,10.77085332
9.042,76.4986,8.460362752
9.736,78.1198,8.023808546
11.73,62.7645,5.350767263
11.448,138.9035,12.13342942
13.226,154.973,11.71729926
24.635,129.3185,5.249380962
34.954,207.9264,5.948572409
45.749,283.1918,6.190120003
56.574,356.1276,6.294898717
"""
df_gain_plugin_jasm = pd.read_csv(io.StringIO(data_text_plugin_jasm))
df_gain_plugin_jasm['VECES_CALCULADO'] = df_gain_plugin_jasm['JASM'] / df_gain_plugin_jasm['TIEMPO_PLUGIN']

# --- Segundo conjunto de datos: TIEMPO_OBJDUMP vs TIEMPO_PLUGIN ---
data_text_objdump_plugin = """
TIEMPO_OBJDUMP,TIEMPO_PLUGIN,VECES
0.319,0.718,2.250783699
0.645,1.34,2.07751938
1.135,2.332,2.054625551
1.549,2.787,1.799225307
1.991,3.853,1.935208438
2.31,4.944,2.14025974
2.735,5.613,2.052285192
3.219,5.836,1.812985399
5.094,9.042,1.775029446
5.7,9.736,1.708070175
6.204,11.73,1.890715667
6.781,11.448,1.688246571
7.306,13.226,1.81029291
14.468,24.635,1.702723251
20.373,34.954,1.715702155
27.169,45.749,1.683867643
34.069,56.574,1.660571194
"""
df_gain_objdump_plugin = pd.read_csv(io.StringIO(data_text_objdump_plugin))
df_gain_objdump_plugin['VECES_CALCULADO'] = df_gain_objdump_plugin['TIEMPO_PLUGIN'] / df_gain_objdump_plugin['TIEMPO_OBJDUMP']


# Crear una figura con 2 subplots en una fila para las dos comparaciones de 'VECES'
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Primer subplot: VECES (Plugin/Objdump) vs. Tiempos (Objdump y Plugin)
sns.regplot(x='TIEMPO_OBJDUMP', y='VECES_CALCULADO', data=df_gain_objdump_plugin, scatter_kws={'alpha':0.6}, label='VECES vs. Tiempo Objdump', ax=axes[0])
sns.regplot(x='TIEMPO_PLUGIN', y='VECES_CALCULADO', data=df_gain_objdump_plugin, scatter_kws={'alpha':0.6}, label='VECES vs. Tiempo Plugin', ax=axes[0])
axes[0].set_title('VECES (Plugin/Objdump) vs. Tiempos')
axes[0].set_xlabel('Tiempo (s)')
axes[0].set_ylabel('VECES (Tiempo Plugin / Tiempo Objdump)')
axes[0].grid(True, linestyle='--', alpha=0.7)
axes[0].legend()
axes[0].set_xscale('log') # Aplicar escala logarítmica al eje X

# Segundo subplot: VECES (JASM/Plugin) vs. Tiempos (Plugin y JASM)
sns.regplot(x='TIEMPO_PLUGIN', y='VECES_CALCULADO', data=df_gain_plugin_jasm, scatter_kws={'alpha':0.6}, label='VECES vs. Tiempo Plugin', ax=axes[1])
sns.regplot(x='JASM', y='VECES_CALCULADO', data=df_gain_plugin_jasm, scatter_kws={'alpha':0.6}, label='VECES vs. Tiempo JASM', ax=axes[1])
axes[1].set_title('VECES (JASM/Plugin) vs. Tiempos')
axes[1].set_xlabel('Tiempo (s)')
axes[1].set_ylabel('VECES (Tiempo JASM / Tiempo Plugin)')
axes[1].grid(True, linestyle='--', alpha=0.7)
axes[1].legend()
axes[1].set_xscale('log') # Aplicar escala logarítmica al eje X

plt.tight_layout()
plt.show()

# %% [markdown]
# lineal

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import io
import numpy as np

# --- Primer conjunto de datos: TIEMPO_PLUGIN vs JASM ---
data_text_plugin_jasm = """
TIEMPO_PLUGIN,JASM,VECES
0.718,10.221,14.23537604
1.34,16.9722,12.6658209
2.332,24.7663,10.62019726
2.787,32.024,11.49049157
3.853,39.7123,10.3068518
4.944,34.6556,7.009627832
5.613,41.2383,7.346926777
5.836,62.8587,10.77085332
9.042,76.4986,8.460362752
9.736,78.1198,8.023808546
11.73,62.7645,5.350767263
11.448,138.9035,12.13342942
13.226,154.973,11.71729926
24.635,129.3185,5.249380962
34.954,207.9264,5.948572409
45.749,283.1918,6.190120003
56.574,356.1276,6.294898717
"""
df_gain_plugin_jasm = pd.read_csv(io.StringIO(data_text_plugin_jasm))
df_gain_plugin_jasm['VECES_CALCULADO'] = df_gain_plugin_jasm['JASM'] / df_gain_plugin_jasm['TIEMPO_PLUGIN']

# --- Segundo conjunto de datos: TIEMPO_OBJDUMP vs TIEMPO_PLUGIN ---
data_text_objdump_plugin = """
TIEMPO_OBJDUMP,TIEMPO_PLUGIN,VECES
0.319,0.718,2.250783699
0.645,1.34,2.07751938
1.135,2.332,2.054625551
1.549,2.787,1.799225307
1.991,3.853,1.935208438
2.31,4.944,2.14025974
2.735,5.613,2.052285192
3.219,5.836,1.812985399
5.094,9.042,1.775029446
5.7,9.736,1.708070175
6.204,11.73,1.890715667
6.781,11.448,1.688246571
7.306,13.226,1.81029291
14.468,24.635,1.702723251
20.373,34.954,1.715702155
27.169,45.749,1.683867643
34.069,56.574,1.660571194
"""
df_gain_objdump_plugin = pd.read_csv(io.StringIO(data_text_objdump_plugin))
df_gain_objdump_plugin['VECES_CALCULADO'] = df_gain_objdump_plugin['TIEMPO_PLUGIN'] / df_gain_objdump_plugin['TIEMPO_OBJDUMP']


# Crear una figura con 2 filas y 2 columnas para un total de 4 subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Primer subplot (arriba izquierda): VECES (Plugin/Objdump) vs. Tiempos (Objdump y Plugin)
sns.lineplot(x='TIEMPO_OBJDUMP', y='VECES_CALCULADO', data=df_gain_objdump_plugin, marker='o', label='VECES vs. Tiempo Objdump', ax=axes[0, 0])
sns.lineplot(x='TIEMPO_PLUGIN', y='VECES_CALCULADO', data=df_gain_objdump_plugin, marker='o', label='VECES vs. Tiempo Plugin', ax=axes[0, 0])
axes[0, 0].set_title('VECES (Plugin/Objdump) vs. Tiempos')
axes[0, 0].set_xlabel('Tiempo (s)')
axes[0, 0].set_ylabel('VECES (Tiempo Plugin / Tiempo Objdump)')
axes[0, 0].set_xlim(0, 60) # Limit X-axis to 0-40
axes[0, 0].set_ylim(1, 3) # Limit Y-axis to 1-3
axes[0, 0].set_yticks(np.arange(1, 3.1, 0.5)) # Set y-ticks from 1 to 3 with 0.5 interval
axes[0, 0].grid(True, linestyle='--', alpha=0.7)
axes[0, 0].legend()

# Segundo subplot (arriba derecha): VECES (JASM/Plugin) vs. Tiempos (Plugin y JASM)
sns.lineplot(x='TIEMPO_PLUGIN', y='VECES_CALCULADO', data=df_gain_plugin_jasm, marker='o', label='VECES vs. Tiempo Plugin', ax=axes[0, 1])
sns.lineplot(x='JASM', y='VECES_CALCULADO', data=df_gain_plugin_jasm, marker='o', label='VECES vs. Tiempo JASM', ax=axes[0, 1])
axes[0, 1].set_title('VECES (JASM/Plugin) vs. Tiempos')
axes[0, 1].set_xlabel('Tiempo (s)')
axes[0, 1].set_ylabel('VECES (Tiempo JASM / Tiempo Plugin)')
axes[0, 1].set_xlim(0, 360) # Limit X-axis to 0-40
axes[0, 1].set_ylim(4, 15) # Limit Y-axis to 1-3
axes[0, 1].grid(True, linestyle='--', alpha=0.7)
axes[0, 1].legend()

# Tercer subplot (abajo izquierda): VECES (Plugin/Objdump) vs. Tiempos (Objdump y Plugin) - limitado a 0-40s
sns.lineplot(x='TIEMPO_OBJDUMP', y='VECES_CALCULADO', data=df_gain_objdump_plugin, marker='o', label='VECES vs. Tiempo Objdump', ax=axes[1, 0])
sns.lineplot(x='TIEMPO_PLUGIN', y='VECES_CALCULADO', data=df_gain_objdump_plugin, marker='o', label='VECES vs. Tiempo Plugin', ax=axes[1, 0])
axes[1, 0].set_title('VECES (Plugin/Objdump) vs. Tiempos (0-40s)')
axes[1, 0].set_xlabel('Tiempo (s)')
axes[1, 0].set_ylabel('VECES (Tiempo Plugin / Tiempo Objdump)')
axes[1, 0].set_xlim(0, 20) # Limit X-axis to 0-40
axes[1, 0].set_ylim(1, 2.5) # Limit Y-axis to 1-3
axes[1, 0].set_yticks(np.arange(1, 2.5, 0.5)) # Set y-ticks from 1 to 3 with 0.5 interval
axes[1, 0].grid(True, linestyle='--', alpha=0.7)
axes[1, 0].legend()

# Cuarto subplot (abajo derecha): VECES (JASM/Plugin) vs. Tiempos (Plugin y JASM) - limitado a 0-40s
sns.lineplot(x='TIEMPO_PLUGIN', y='VECES_CALCULADO', data=df_gain_plugin_jasm, marker='o', label='VECES vs. Tiempo Plugin', ax=axes[1, 1])
sns.lineplot(x='JASM', y='VECES_CALCULADO', data=df_gain_plugin_jasm, marker='o', label='VECES vs. Tiempo JASM', ax=axes[1, 1])
axes[1, 1].set_title('VECES (JASM/Plugin) vs. Tiempos (0-40s)')
axes[1, 1].set_xlabel('Tiempo (s)')
axes[1, 1].set_ylabel('VECES (Tiempo JASM / Tiempo Plugin)')
axes[1, 1].set_xlim(0, 40) # Limit X-axis to 0-40
axes[1, 1].set_xlim(0, 50) # Limit X-axis to 0-40
axes[1, 1].set_ylim(4, 15) # Limit Y-axis to 1-3
axes[1, 1].grid(True, linestyle='--', alpha=0.7)
axes[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
#
# ## Comparative Performance Analysis: Plugin vs. JASM vs. Objdump
#
# This analysis compared the performance of three binary disassembly and analysis tools: native Objdump, the developed plugin for Objdump, and JASM (a parsing tool based on Objdump).
#
# ### Main Results
#
# The results obtained demonstrate that the developed plugin maintains efficiency comparable to native Objdump, with minimal overhead. Processing approximately 17 million instructions, the plugin required only 60 seconds, while JASM needed approximately 350 seconds for the same workload.
#
# ### Scalability
#
# The scalability analysis revealed significant differences between the tools:
#
# - **Plugin and native Objdump**: Both exhibit linear time growth O(n), indicating optimal scalability proportional to the number of instructions processed and the binary size.
#
# - **JASM**: Exhibits a more pronounced time growth, suggesting higher algorithmic complexity, possibly O(n log n) or greater, due to the overhead introduced by the additional parsing operations.
#
# ### Plugin Efficiency
#
# The efficiency of the developed plugin is attributed to the following implemented optimizations:
#
# 1. **Efficient Pre-filtering**: Use of key character search (`find()`) before applying regular expressions, reducing the number of costly regex operations.
#
# 2. **Optimized Memory Management**: Single assignment of strings using `assign()`, avoiding redundant copies in each instruction callback.
#
# 3. **Direct I/O**: Direct write to file using `fprintf()`, minimizing buffering overhead and type conversions.
#
# 4. **Callback Architecture**: Native integration with the Objdump disassembly flow, avoiding data reprocessing.
#
# ### JASM Overhead
#
# JASM exhibits a 5-7x performance overhead compared to the developed plugin. This difference is primarily due to:
#
# - Two-stage processing: disassembly followed by parsing
# - Additional data transformations
# - Potential use of less efficient data structures for analysis
#
# ### Relative Performance Analysis
#
# Further relative performance analysis was performed by calculating the execution time ratios between the different tools.
#
# #### Plugin/Objdump Ratio
#
# The time ratio analysis (Plugin/Objdump) reveals that the plugin introduces approximately **1.5-2.0x** overhead compared to native Objdump. This overhead is attributable to:
#
# - Regular expression processing for pattern detection
# - Writing results to an output file
# - Callback invocations for each processed instruction
#
# Notably, this ratio shows a downward trend as processing time increases, converging to approximately 1.6x for larger binaries. This behavior indicates that the plugin's fixed overhead is efficiently amortized with larger workloads, and that the callback architecture scales appropriately.
#
# #### JASM/Plugin Ratio
#
# The time ratio (JASM/Plugin) exhibits significant variability in the range of **5-14×**, with the following findings:
#
# - For small binaries (< 10s processing time): JASM overhead reaches peaks of up to 14× due to the cost of initialization and structural parsing.
# - For medium binaries (10-100s): The ratio stabilizes in the range of 6-12×.
# - For large binaries (> 100s): The ratio tends to stabilize around 6-8×.
#
# The high variability observed in the JASM/Plugin metric suggests that JASM's performance is more sensitive to the specific characteristics of the analyzed binary (structural complexity, symbol density, etc.), while the plugin maintains more predictable and consistent behavior.
#
# #### Explanation of Variability in Ratios
#
# The variability observed in the ratio (TIMES) graphs does not indicate an implementation problem, but rather is expected behavior due to several factors:
#
# 1. **Fixed vs. Proportional Overhead**: Each tool has fixed costs (initialization, library loading, header parsing) and proportional costs (instruction processing). For small binaries, fixed overhead dominates, causing higher and more variable ratios. For large binaries, proportional overhead dominates, stabilizing the ratios.
#
# 2. **Amplification of Variations in the Ratio**: While absolute times (first graph) show stable linear growth, when calculating ratios, small absolute variations are amplified. For example:
#
# - If Plugin = 5s and Objdump = 3s → Ratio = 1.67×
#
# - If Plugin = 5.5s and Objdump = 3s → Ratio = 1.83×
#
# - A variation of 0.5s (10%) produces a 16% change in ratio
#
# 3. **Variable characteristics of binaries**: Different binaries have different ins ratios
